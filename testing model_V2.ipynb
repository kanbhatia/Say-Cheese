# %%
# Load the model
import numpy as np
import matplotlib.pyplot as plt
import os
# import cv2
import cv2
# import os
import tensorflow as tf
from tensorflow.keras.models import load_model
model = load_model("100_epochs.h5")

# %%
Datadir = "PetImages"
CATEGORIES = ["Dog","Cat"]

# %%
def prepare(filepath):
    path = os.path.join(filepath)
    for img in os.listdir(path):
        IMG_SIZE = 50
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
        plt.imshow(img_array, cmap = "gray")

        break
    return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
# LOADING DOG
asd = prepare("")
# Out:
# 'https://thispersondoesnotexist.com/image'

# %%
path = "test/female.jpg"
IMG_SIZE = 100

# %%
img_array = cv2.imread(os.path.join(path), cv2.IMREAD_GRAYSCALE)
new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(img_array, cmap = "gray")

# %%
X = np.array(new_array).reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
X = X/255

# %%
if (model.predict(X)<.3):
    print(f"Male with {(1-model.predict(X))*100}")
else:
        print(f"Female with {(model.predict(X))*100}")
# Out:
# Female with [[99.858864]]

# %%
from tensorflow.keras.preprocessing.image import img_to_array
image = img_to_array(im)
image.shape
# Out:
# (100, 100, 1)

# %%
from tensorflow.keras.preprocessing import image
image_size = (100, 100)
im = image.load_img(filepath, target_size=image_size, color_mode="grayscale")
im
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x2112F09B0F0>

# %%
image /= 255

# Flatten into a 1x28*28 array 
img = image.flatten().reshape(-1, 100*100)
img.shape
# Out:
# (1, 10000)

# %%
plt.imshow(img.reshape(100, 100), cmap=plt.cm.Greys)

# %%
# Invert the pixel values to match the original data
img = 1 - img
plt.imshow(img.reshape(100, 100), cmap=plt.cm.Greys)

# %%
model.predict_classes(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c487e2267fc1> in <module>
# ----> 1 model.predict_classes(img)
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py in predict_classes(self, x, batch_size, verbose)
#     325         A numpy array of class predictions.
#     326     """
# --> 327     proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#     328     if proba.shape[-1] > 1:
#     329       return proba.argmax(axis=-1)
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     907         max_queue_size=max_queue_size,
#     908         workers=workers,
# --> 909         use_multiprocessing=use_multiprocessing)
#     910
#     911   def reset_metrics(self):
#
# ...
